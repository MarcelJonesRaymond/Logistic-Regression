# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
data=pd.read_csv("pima-indians-diabetes.csv")
data.head()
# Out:
#    Preg  Plas  Pres  skin  test  mass   pedi  age  class
# 0     6   148    72    35     0  33.6  0.627   50      1
# 1     1    85    66    29     0  26.6  0.351   31      0
# 2     8   183    64     0     0  23.3  0.672   32      1
# 3     1    89    66    23    94  28.1  0.167   21      0
# 4     0   137    40    35   168  43.1  2.288   33      1

# %%
data.tail()
# Out:
#      Preg  Plas  Pres  skin  test  mass   pedi  age  class
# 763    10   101    76    48   180  32.9  0.171   63      0
# 764     2   122    70    27     0  36.8  0.340   27      0
# 765     5   121    72    23   112  26.2  0.245   30      0
# 766     1   126    60     0     0  30.1  0.349   47      1
# 767     1    93    70    31     0  30.4  0.315   23      0

# %%
data.shape
# Out:
# (768, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Preg    768 non-null    int64
#  1   Plas    768 non-null    int64
#  2   Pres    768 non-null    int64
#  3   skin    768 non-null    int64
#  4   test    768 non-null    int64
#  5   mass    768 non-null    float64
#  6   pedi    768 non-null    float64
#  7   age     768 non-null    int64
#  8   class   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.isna().sum()
# Out:
# Preg     0
# Plas     0
# Pres     0
# skin     0
# test     0
# mass     0
# pedi     0
# age      0
# class    0
# dtype: int64

# %%
data.describe()
# Out:
#              Preg        Plas        Pres        skin        test        mass  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#              pedi         age       class
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# 50%      0.372500   29.000000    0.000000
# 75%      0.626250   41.000000    1.000000
# max      2.420000   81.000000    1.000000

# %%
data.corr().style.background_gradient("magma")
# Out:
# <style  type="text/css" >
# #T_8e1ce_row0_col0,#T_8e1ce_row1_col1,#T_8e1ce_row2_col2,#T_8e1ce_row3_col3,#T_8e1ce_row4_col4,#T_8e1ce_row5_col5,#T_8e1ce_row6_col6,#T_8e1ce_row7_col7,#T_8e1ce_row8_col8{
#             background-color:  #fcfdbf;
#             color:  #000000;
#         }#T_8e1ce_row0_col1{
#             background-color:  #0d0a29;
#             color:  #f1f1f1;
#         }#T_8e1ce_row0_col2{
#             background-color:  #150e38;
#             color:  #f1f1f1;
#         }#T_8e1ce_row0_col3,#T_8e1ce_row7_col4{
#             background-color:  #03030f;
#             color:  #f1f1f1;
#         }#T_8e1ce_row0_col4,#T_8e1ce_row0_col5,#T_8e1ce_row0_col6,#T_8e1ce_row2_col8,#T_8e1ce_row3_col0,#T_8e1ce_row3_col1,#T_8e1ce_row3_col7,#T_8e1ce_row6_col2,#T_8e1ce_row7_col3{
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }#T_8e1ce_row0_col7{
#             background-color:  #db476a;
#             color:  #000000;
#         }#T_8e1ce_row0_col8,#T_8e1ce_row1_col6{
#             background-color:  #2c115f;
#             color:  #f1f1f1;
#         }#T_8e1ce_row1_col0{
#             background-color:  #38106c;
#             color:  #f1f1f1;
#         }#T_8e1ce_row1_col2,#T_8e1ce_row6_col8{
#             background-color:  #19103f;
#             color:  #f1f1f1;
#         }#T_8e1ce_row1_col3{
#             background-color:  #271258;
#             color:  #f1f1f1;
#         }#T_8e1ce_row1_col4{
#             background-color:  #832681;
#             color:  #f1f1f1;
#         }#T_8e1ce_row1_col5,#T_8e1ce_row3_col6{
#             background-color:  #3f0f72;
#             color:  #f1f1f1;
#         }#T_8e1ce_row1_col7{
#             background-color:  #732081;
#             color:  #f1f1f1;
#         }#T_8e1ce_row1_col8{
#             background-color:  #982d80;
#             color:  #f1f1f1;
#         }#T_8e1ce_row2_col0,#T_8e1ce_row7_col2{
#             background-color:  #3d0f71;
#             color:  #f1f1f1;
#         }#T_8e1ce_row2_col1{
#             background-color:  #140e36;
#             color:  #f1f1f1;
#         }#T_8e1ce_row2_col3{
#             background-color:  #5f187f;
#             color:  #f1f1f1;
#         }#T_8e1ce_row2_col4{
#             background-color:  #251255;
#             color:  #f1f1f1;
#         }#T_8e1ce_row2_col5,#T_8e1ce_row6_col3{
#             background-color:  #57157e;
#             color:  #f1f1f1;
#         }#T_8e1ce_row2_col6{
#             background-color:  #0c0926;
#             color:  #f1f1f1;
#         }#T_8e1ce_row2_col7{
#             background-color:  #6b1d81;
#             color:  #f1f1f1;
#         }#T_8e1ce_row3_col2,#T_8e1ce_row5_col1{
#             background-color:  #2f1163;
#             color:  #f1f1f1;
#         }#T_8e1ce_row3_col4{
#             background-color:  #ab337c;
#             color:  #f1f1f1;
#         }#T_8e1ce_row3_col5{
#             background-color:  #842681;
#             color:  #f1f1f1;
#         }#T_8e1ce_row3_col8{
#             background-color:  #010106;
#             color:  #f1f1f1;
#         }#T_8e1ce_row4_col0{
#             background-color:  #010005;
#             color:  #f1f1f1;
#         }#T_8e1ce_row4_col1{
#             background-color:  #601880;
#             color:  #f1f1f1;
#         }#T_8e1ce_row4_col2{
#             background-color:  #06051a;
#             color:  #f1f1f1;
#         }#T_8e1ce_row4_col3{
#             background-color:  #b3367a;
#             color:  #f1f1f1;
#         }#T_8e1ce_row4_col5{
#             background-color:  #331067;
#             color:  #f1f1f1;
#         }#T_8e1ce_row4_col6{
#             background-color:  #400f74;
#             color:  #f1f1f1;
#         }#T_8e1ce_row4_col7,#T_8e1ce_row7_col6{
#             background-color:  #0a0822;
#             color:  #f1f1f1;
#         }#T_8e1ce_row4_col8{
#             background-color:  #0b0924;
#             color:  #f1f1f1;
#         }#T_8e1ce_row5_col0{
#             background-color:  #120d31;
#             color:  #f1f1f1;
#         }#T_8e1ce_row5_col2,#T_8e1ce_row5_col4{
#             background-color:  #51127c;
#             color:  #f1f1f1;
#         }#T_8e1ce_row5_col3{
#             background-color:  #a3307e;
#             color:  #f1f1f1;
#         }#T_8e1ce_row5_col6,#T_8e1ce_row8_col3{
#             background-color:  #2d1161;
#             color:  #f1f1f1;
#         }#T_8e1ce_row5_col7{
#             background-color:  #20114b;
#             color:  #f1f1f1;
#         }#T_8e1ce_row5_col8{
#             background-color:  #4e117b;
#             color:  #f1f1f1;
#         }#T_8e1ce_row6_col0{
#             background-color:  #060518;
#             color:  #f1f1f1;
#         }#T_8e1ce_row6_col1{
#             background-color:  #100b2d;
#             color:  #f1f1f1;
#         }#T_8e1ce_row6_col4{
#             background-color:  #4c117a;
#             color:  #f1f1f1;
#         }#T_8e1ce_row6_col5{
#             background-color:  #1d1147;
#             color:  #f1f1f1;
#         }#T_8e1ce_row6_col7{
#             background-color:  #1e1149;
#             color:  #f1f1f1;
#         }#T_8e1ce_row7_col0{
#             background-color:  #d6456c;
#             color:  #f1f1f1;
#         }#T_8e1ce_row7_col1{
#             background-color:  #420f75;
#             color:  #f1f1f1;
#         }#T_8e1ce_row7_col5{
#             background-color:  #020109;
#             color:  #f1f1f1;
#         }#T_8e1ce_row7_col8{
#             background-color:  #341069;
#             color:  #f1f1f1;
#         }#T_8e1ce_row8_col0,#T_8e1ce_row8_col5{
#             background-color:  #5c167f;
#             color:  #f1f1f1;
#         }#T_8e1ce_row8_col1{
#             background-color:  #9b2e7f;
#             color:  #f1f1f1;
#         }#T_8e1ce_row8_col2{
#             background-color:  #02020d;
#             color:  #f1f1f1;
#         }#T_8e1ce_row8_col4{
#             background-color:  #36106b;
#             color:  #f1f1f1;
#         }#T_8e1ce_row8_col6{
#             background-color:  #3b0f70;
#             color:  #f1f1f1;
#         }#T_8e1ce_row8_col7{
#             background-color:  #6a1c81;
#             color:  #f1f1f1;
#         }</style><table id="T_8e1ce_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Preg</th>        <th class="col_heading level0 col1" >Plas</th>        <th class="col_heading level0 col2" >Pres</th>        <th class="col_heading level0 col3" >skin</th>        <th class="col_heading level0 col4" >test</th>        <th class="col_heading level0 col5" >mass</th>        <th class="col_heading level0 col6" >pedi</th>        <th class="col_heading level0 col7" >age</th>        <th class="col_heading level0 col8" >class</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8e1ce_level0_row0" class="row_heading level0 row0" >Preg</th>
#                         <td id="T_8e1ce_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_8e1ce_row0_col1" class="data row0 col1" >0.129459</td>
#                         <td id="T_8e1ce_row0_col2" class="data row0 col2" >0.141282</td>
#                         <td id="T_8e1ce_row0_col3" class="data row0 col3" >-0.081672</td>
#                         <td id="T_8e1ce_row0_col4" class="data row0 col4" >-0.073535</td>
#                         <td id="T_8e1ce_row0_col5" class="data row0 col5" >0.017683</td>
#                         <td id="T_8e1ce_row0_col6" class="data row0 col6" >-0.033523</td>
#                         <td id="T_8e1ce_row0_col7" class="data row0 col7" >0.544341</td>
#                         <td id="T_8e1ce_row0_col8" class="data row0 col8" >0.221898</td>
#             </tr>
#             <tr>
#                         <th id="T_8e1ce_level0_row1" class="row_heading level0 row1" >Plas</th>
#                         <td id="T_8e1ce_row1_col0" class="data row1 col0" >0.129459</td>
#                         <td id="T_8e1ce_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_8e1ce_row1_col2" class="data row1 col2" >0.152590</td>
#                         <td id="T_8e1ce_row1_col3" class="data row1 col3" >0.057328</td>
#                         <td id="T_8e1ce_row1_col4" class="data row1 col4" >0.331357</td>
#                         <td id="T_8e1ce_row1_col5" class="data row1 col5" >0.

# %%
data["age"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.pairplot(data,kind="reg")

# %%
x=data.drop("class",axis=1)
y=data[["class"]]

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X=scaler.fit_transform(x)

# %%
X=pd.DataFrame(X,columns=x.columns)

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1)

# %%
import warnings
warnings.filterwarnings('ignore')
from sklearn.naive_bayes import GaussianNB
GNB=GaussianNB()
GNB.fit(x_train,y_train)
yhat=GNB.predict(x_test)

# %%
metrics.accuracy_score(y_test,yhat)
# Out:
# 0.7835497835497836

# %%
metrics.plot_confusion_matrix(GNB,x_test,y_test)

# %%
print(metrics.classification_report(y_test,yhat))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.88      0.84       146
#            1       0.75      0.62      0.68        85
#
#     accuracy                           0.78       231
#    macro avg       0.77      0.75      0.76       231
# weighted avg       0.78      0.78      0.78       231
